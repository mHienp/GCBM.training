# %% [markdown]
# ### Inventory

# %%
inventory = gpd.read_file('/content/2_Sample_Data/Spatial/Inventory/inv_sample.shp')

# %%
inventory.head(1)
# Out:
#    OBJECTID  Age   AU          LdSpp  Shape_Leng    Shape_Area  \
# 0         1  187  597  Western larch    0.005083  1.403386e-08
#
#                                             geometry
# 0  MULTIPOLYGON (((-119.28739 49.07604, -119.2867...

# %%
# age
# AU
# LdSpp
plt.show()

# %% [markdown]
# ### Yield curves

# %%
df = pd.read_csv('/content/2_Sample_Data/Aspatial/yield_curves.csv')
df
# Out:
#                  LdSpp                   AIDB Species  Age0      Age10  \
# 0             Redcedar               Western redcedar     0  33.680710
# 1       Lodgepole pine                 Lodgepole pine     0  30.965987
# 2     Engelmann spruce               Engelmann spruce     0  33.680710
# 3        Western larch                  Western larch     0  44.853576
# 4        Subalpine fir  Subalpine fir (or alpine fir)     0  31.424802
# 5          Douglas-fir       Douglas-fir - Genus type     0  32.007142
# 6               Spruce                         Spruce     0  19.819427
# 7                Aspen                Trembling aspen     0  14.010180
# 8               Poplar                  Balsam poplar     0  30.965987
# 9          Paper birch           Mountain paper birch     0  33.680710
# 10     Western hemlock                Western hemlock     0  44.853576
# 11      Ponderosa pine                 Ponderosa pine     0  31.424802
# ...

# %% [markdown]
# ### Insect

# %%
# insect layer 1990
mpb1990 = gpd.read_file('/content/2_Sample_Data/Spatial/Disturbances/Insect/mpb1990.shp')

# %%
mpb1990.head(1)
# Out:
#           AREA   PERIMETER  BCMPB1990_  BCMPB19901 PEST REGION    NTS  \
# 0  1762.704031  169.646869        3071         469  mpb     ka  82ene
#
#   SEVERITY  YEAR_       HA SOURCE  Shape_Leng  Shape_Area  \
# 0        3   1990  0.17627   FIDS  169.647113  1762.70234
#
#                                             geometry
# 0  POLYGON ((-118.57545 49.88820, -118.57603 49.8...

# %%
# insect all years
dir = '/content/2_Sample_Data/Spatial/Disturbances/Insect'
years = list(range(1990, 1997)) + list(range(1999, 2001))
plt.show()
