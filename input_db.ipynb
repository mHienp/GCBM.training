# %%
import sqlite3
import pandas as pd

# %%
conn = sqlite3.connect("/content/gcbm_input.db")

# %%
# Create cursor object
cur = conn.cursor()

# Execute SQL query to get table names
cur.execute("SELECT name FROM sqlite_master WHERE type='table';")

# Get the result set as a list of tuples
result = cur.fetchall()

print("The database has", len(result), "tables.")
# Out:
# The database has 41 tables.

# %%
# Create empty list to hold table names
table_names = [row[0] for row in result]

for table_name in table_names:
    print(table_name)
# Out:
# classifier_value
# classifier
# spatial_unit
# admin_boundary
# eco_boundary
# disturbance_matrix
# disturbance_matrix_value
# pool
# decay_parameter
# spinup_parameter
# dom_pool
# transition
# transition_classifier_value
# land_class
# admin_region
# eco_region
# disturbance_type
# disturbance_matrix_association
# forest_type
# genus
# species
# vol_to_bio_factor
# vol_to_bio_factor_association
# growth_curve
# growth_curve_component
# growth_curve_component_value
# growth_curve_classifier_value
# root_parameter
# growth_multiplier_series
# growth_multiplier_value
# growth_multiplier_series_association
# stump_parameter
# turnover_parameter
# transition_type
# transition_rule
# transition_rule_classifier_value
# disturbance_category
# accounting_rule_set
# accounting_rule_type
# accounting_rule
# turnover_parameter_association

# %%
# Loop through each table and load it into a df
df_list = []
for table_name in table_names:
    df = pd.read_sql_query(f"SELECT * FROM {table_name}", conn)
    globals()[table_name] = df
    df_list.append(df)

# %%
classifier_value
# Out:
#     id  classifier_id value description
# 0    1              1    BF          BF
# 1    2              1    BP          BP
# 2    3              1    BS          BS
# 3    4              1    GA          GA
# 4    5              1    JP          JP
# 5    6              1    TA          TA
# 6    7              1    WB          WB
# 7    8              1    WS          WS
# 8    9              1     ?           ?
# 9   10              2     7           7
# 10  11              2     5           5
# 11  12              2     6           6
# 12  13              2     8           8
# 13  14              2     ?           ?

# %%
classifier.tail()
# Out:
#    id         name
# 0   1  Classifier1
# 1   2  Classifier2

# %%
spatial_unit.tail()
# Out:
#     id  admin_boundary_id  eco_boundary_id  spinup_parameter_id
# 43  44                 13                6                   13
# 44  45                 13                8                    5
# 45  46                 13                9                   11
# 46  47                 14                2                    2
# 47  48                 14               12                   18

# %%
admin_boundary
# Out:
#     id                   name  admin_region_id  stump_parameter_id
# 0    1           Newfoundland                1                   4
# 1    2               Labrador                2                   4
# 2    3            Nova Scotia                3                   2
# 3    4   Prince Edward Island                4                   6
# 4    5          New Brunswick                5                   6
# 5    6                 Quebec                6                   7
# 6    7                Ontario                7                   3
# 7    8               Manitoba                8                   5
# 8    9           Saskatchewan                9                   3
# 9   10                Alberta               10                   3
# 10  11       British Columbia               11                   1
# 11  12        Yukon Territory               12                   8
# 12  13  Northwest Territories               13                   9
# ...

# %%
eco_boundary
# Out:
#     id                name  eco_region_id
# 0    1        Taiga Plains              1
# 1    2   Taiga Shield West              2
# 2    3  Boreal Shield West              3
# 3    4   Atlantic Maritime              4
# 4    5    Mixedwood Plains              5
# 5    6       Boreal Plains              6
# 6    7   Subhumid Prairies              7
# 7    8    Taiga Cordillera              8
# 8    9   Boreal Cordillera              9
# 9   10    Pacific Maritime             10
# 10  11  Montane Cordillera             11
# 11  12       Hudson Plains             12
# 12  13   Taiga Shield East             13
# 13  14  Boreal Shield East             14
# 14  15   Semiarid Prairies             15

# %%
disturbance_matrix.tail()
# Out:
#       id                                               name
# 193  194  407_Wildfire for Labrador - Taiga Shield East ...
# 194  195  408_Wildfire for Nunavut - Taiga Shield West (...
# 195  196                         424_Firewood Collection-SW
# 196  197                         425_Firewood Collection-HW
# 197  198                        426_DOM Firewood Collection

# %%
disturbance_matrix_value.tail()
# Out:
#        disturbance_matrix_id  source_pool_id  sink_pool_id  proportion
# 10558                    194              29            28         1.0
# 10559                    195              29            28         1.0
# 10560                    196              29            29         1.0
# 10561                    197              29            29         1.0
# 10562                    198              29            29         1.0

# %%
pool.tail()
# Out:
#     id         name
# 24  25          NO2
# 25  26     Products
# 26  27   Atmosphere
# 27  28  BlackCarbon
# 28  29         Peat

# %%
decay_parameter
# Out:
#     dom_pool_id  base_decay_rate  reference_temp   q10  prop_to_atmosphere  \
# 0             3          0.35500            10.0  2.65               0.815
# 1             6          0.50000            10.0  2.00               0.830
# 2             1          0.14350            10.0  2.00               0.830
# 3             4          0.14350            10.0  2.00               0.830
# 4             9          0.03740            10.0  2.00               0.830
# 5             2          0.01500            10.0  2.65               1.000
# 6             5          0.00330            10.0  1.00               1.000
# 7            11          0.01870            10.0  2.00               0.830
# 8            10          0.07175            10.0  2.00               0.830
# 9             8          0.01870            10.0  2.00               0.830
# 10            7          0.07175            10.0  2.00               0.830
#
#     max_rate
# 0        1.0
# 1        1.0
# 2        1.0
# ...

# %%
spinup_parameter.tail()
# Out:
#     id  historic_disturbance_type_id  return_interval  max_rotations  \
# 43  44                             2              125             30
# 44  45                             2              300             30
# 45  46                             2              125             30
# 46  47                             2              125             30
# 47  48                             2              125             30
#
#     mean_annual_temperature
# 43                     5.08
# 44                     5.21
# 45                     5.36
# 46                     5.86
# 47                     6.32

# %%
dom_pool.tail()
# Out:
#     id  pool_id
# 6    7       21
# 7    8       20
# 8    9       15
# 9   10       19
# 10  11       18

# %%
transition.tail()
# Out:
#    id  transition_type_id  age  regen_delay description
# 0   1                   1    0            0           1

# %%
transition_classifier_value.tail()
# Out:
#    transition_id  classifier_value_id
# 0              1                    9
# 1              1                   14

# %%
land_class
# Out:
#    id code            description  is_forest  years_to_permanent
# 0   1   FL            Forest land          1                  20
# 1   2  UFL  Unmanaged forest land          1                  20
# 2   3   CL               Cropland          0                  20
# 3   4   GL              Grassland          0                  20
# 4   5   WL                Wetland          0                  10
# 5   6   SL            Settlements          0                  20
# 6   7   OL             Other land          0                  20

# %%
admin_region
# Out:
#     id                   name
# 0    1           Newfoundland
# 1    2               Labrador
# 2    3            Nova Scotia
# 3    4   Prince Edward Island
# 4    5          New Brunswick
# 5    6                 Quebec
# 6    7                Ontario
# 7    8               Manitoba
# 8    9           Saskatchewan
# 9   10                Alberta
# 10  11       British Columbia
# 11  12        Yukon Territory
# 12  13  Northwest Territories
# 13  14                Nunavut

# %%
eco_region
# Out:
#     id                name
# 0    1        Taiga Plains
# 1    2   Taiga Shield West
# 2    3  Boreal Shield West
# 3    4   Atlantic Maritime
# 4    5    Mixedwood Plains
# 5    6       Boreal Plains
# 6    7   Subhumid Prairies
# 7    8    Taiga Cordillera
# 8    9   Boreal Cordillera
# 9   10    Pacific Maritime
# 10  11  Montane Cordillera
# 11  12       Hudson Plains
# 12  13   Taiga Shield East
# 13  14  Boreal Shield East
# 14  15   Semiarid Prairies

# %%
disturbance_type.tail()
# Out:
#       id  disturbance_category_id  transition_land_class_id  \
# 102  103                        1                       5.0
# 103  104                        1                       NaN
# 104  105                        1                       NaN
# 105  106                        1                       NaN
# 106  107                        1                       NaN
#
#                                                   name  code
# 102  Deforestation — Hydro reservoir — salvage and ...   235
# 103                           Firewood Collection - SW   236
# 104                           Firewood Collection - HW   237
# 105                 Firewood Collection - post logging   238
# 106    Firewood Collection - post natural disturbance    239

# %%
disturbance_matrix_association.tail()
# Out:
#       spatial_unit_id  disturbance_type_id  disturbance_matrix_id
# 4829               38                   35                     32
# 4830               38                   33                     33
# 4831               38                   77                     91
# 4832               38                    1                     20
# 4833               38                    2                    174

# %%
forest_type.tail()
# Out:
#    id            name
# 0   1        Softwood
# 1   2       Mixedwood
# 2   3        Hardwood
# 3   4  Not Applicable

# %%
genus
# Out:
#     id                              name
# 0    1                            Spruce
# 1    2                              Pine
# 2    3                               Fir
# 3    4                           Hemlock
# 4    5                       Douglas-fir
# 5    6                             Larch
# 6    7          Cedar and other conifers
# 7    8              Unspecified conifirs
# 8    9                            Poplar
# 9   10                             Birch
# 10  11                             Maple
# 11  12        Other broad-leaved species
# 12  13  Unspecified broad-leaved species
# 13  14                     Missing Value
# 14  15                    Not applicable

# %%
species.tail()
# Out:
#       id                                          name  forest_type_id  \
# 189  190                            Maple - Genus type               3
# 190  191        Other broadleaved species - Genus type               3
# 191  192  Unspecified broadleaved species - Genus type               3
# 192  193                          Hardwood forest type               3
# 193  194                                   Not stocked               4
#
#      genus_id
# 189        11
# 190        12
# 191        13
# 192        14
# 193        14

# %%
vol_to_bio_factor.tail()
# Out:
#       id        a        b  a_nonmerch  b_nonmerch  k_nonmerch  cap_nonmerch  \
# 594  595   3.5074  0.69873      5.5532    -0.78239     0.84909        1.8035
# 595  596   3.9792  0.61959    100.0000    -1.72498     1.03094        1.9924
# 596  597   9.6032  0.46891     88.8986    -1.87112     1.05439        3.0118
# 597  598  12.0225  0.49640    100.0000    -1.90309     0.99573        1.8373
# 598  599  12.4077  0.39162      5.5532    -0.78239     0.84909        1.8035
#
#      a_sap  b_sap  k_sap  ...  min_volume  max_volume  low_stemwood_prop  \
# 594    0.0    0.0    1.0  ...        0.47      139.09            0.76152
# 595    0.0    0.0    1.0  ...        0.43      117.78            0.74378
# 596    0.0    0.0    1.0  ...        0.37      328.70            0.76798
# 597    0.0    0.0    1.0  ...        2.67      153.57            0.69632
# 598    0.0    0.0    1.0  ...        0.46       67.80            0.75735
#
# ...

# %%
vol_to_bio_factor_association.tail()
# Out:
#       spatial_unit_id  species_id  vol_to_bio_factor_id  root_parameter_id
# 9307               48         190                   186                  1
# 9308               48         191                   186                  1
# 9309               48          72                   376                  1
# 9310               48          73                   376                  1
# 9311               48         193                   186                  1

# %%
growth_curve
# Out:
#    id description
# 0   1        BF,7
# 1   2        BP,5
# 2   3        BP,6
# 3   4        BS,5
# 4   5        GA,8
# 5   6        JP,6
# 6   7        TA,5
# 7   8        TA,7
# 8   9        WB,7
# 9  10        WS,6

# %%
growth_curve_component
# Out:
#    id  growth_curve_id  species_id
# 0   1                1          75
# 1   2                2          29
# 2   3                3          31
# 3   4                4          36
# 4   5                5          39
# 5   6                6          17
# 6   7                7          15
# 7   8                8           1
# 8   9                9           1
# 9  10               10          75

# %%
growth_curve_component_value.tail()
# Out:
#      growth_curve_component_id  age  merchantable_volume
# 355                         10  310                191.1
# 356                         10  320                191.2
# 357                         10  330                191.2
# 358                         10  340                191.2
# 359                         10  350                191.2

# %%
growth_curve_classifier_value.tail()
# Out:
#     growth_curve_id  classifier_value_id
# 15                8                   10
# 16                9                    7
# 17                9                   10
# 18               10                    8
# 19               10                   12

# %%
root_parameter.tail()
# Out:
#    id   hw_a   sw_a   hw_b  frp_a  frp_b     frp_c
# 0   1  1.576  0.222  0.615  0.072  0.354 -0.060212

# %%
growth_multiplier_series
# Out:
#    id                 description
# 0   1  Aspen Defoliators — Type A
# 1   2  Aspen Defoliators — Type B
# 2   3  Aspen Defoliators — Type C
# 3   4  Aspen Defoliators — Type D
# 4   5  Aspen Defoliators — Type E
# 5   6  Aspen Defoliators — Type F
# 6   7  WJPBW — Year 1 of outbreak
# 7   8  WJPBW — Year 2 of outbreak
# 8   9  WJPBW — Year 3 of outbreak
# 9  10  WJPBW — Year 4 of outbreak

# %%
growth_multiplier_value.tail()
# Out:
#     growth_multiplier_series_id  forest_type_id  time_step  value
# 24                            9               1          2   0.40
# 25                            9               1          3   0.70
# 26                           10               1          1   0.05
# 27                           10               1          2   0.40
# 28                           10               1          3   0.70

# %%
growth_multiplier_series_association.tail()
# Out:
#    disturbance_type_id  growth_multiplier_series_id
# 5                   22                            6
# 6                   13                            7
# 7                   14                            8
# 8                   15                            9
# 9                   16                           10

# %%
stump_parameter.tail()
# Out:
#    id  sw_top_proportion  sw_stump_proportion  hw_top_proportion  \
# 4   5              2.851                5.390              4.453
# 5   6              3.418                2.807              5.196
# 6   7              5.183                2.807              7.406
# 7   8              7.521                5.390             10.169
# 8   9              8.067                5.390             10.793
#
#    hw_stump_proportion
# 4                5.520
# 5                2.875
# 6                2.875
# 7                5.520
# 8                5.520

# %%
turnover_parameter
# Out:
#     id  foliage    stem  branch  stem_snag  branch_snag  coarse_root  \
# 0    1     0.05  0.0060    0.03      0.032          0.1         0.02
# 1    2     0.10  0.0045    0.04      0.032          0.1         0.02
# 2    3     0.10  0.0050    0.04      0.032          0.1         0.02
# 3    4     0.10  0.0060    0.04      0.032          0.1         0.02
# 4    5     0.15  0.0060    0.04      0.032          0.1         0.02
# 5    6     0.15  0.0067    0.04      0.032          0.1         0.02
# 6    7     0.95  0.0045    0.04      0.032          0.1         0.02
# 7    8     0.95  0.0050    0.04      0.032          0.1         0.02
# 8    9     0.95  0.0060    0.03      0.032          0.1         0.02
# 9   10     0.95  0.0060    0.04      0.032          0.1         0.02
# 10  11     0.95  0.0067    0.04      0.032          0.1         0.02
#
#     fine_root  branch_snag_split  coarse_ag_split  fine_ag_split
# 0       0.641               0.25              0.5            0.5
# ...

# %%
transition_type.tail()
# Out:
#    id      name
# 0   1  absolute
# 1   2  relative
# 2   3     yield

# %%
transition_rule.tail()
# Out:
# Empty DataFrame
# Columns: [id, transition_id, disturbance_type_id]
# Index: []

# %%
transition_rule_classifier_value.tail()
# Out:
# Empty DataFrame
# Columns: [transition_rule_id, classifier_value_id]
# Index: []

# %%
disturbance_category.tail()
# Out:
#    id code              description
# 0   1    A  Anthropogenic influence
# 1   2    N      Naturally disturbed

# %%
accounting_rule_set.tail()
# Out:
# Empty DataFrame
# Columns: [id, disturbance_type_id, spatial_unit_id]
# Index: []

# %%
accounting_rule_type.tail()
# Out:
#    id                               name  spinup
# 0   1  years_since_last_pass_disturbance       1
# 1   2            years_since_disturbance       0
# 2   3                         ag_biomass       0
# 3   4                      total_biomass       0
# 4   5                          total_eco       0

# %%
accounting_rule.tail()
# Out:
# Empty DataFrame
# Columns: [accounting_rule_set_id, accounting_rule_type_id, value]
# Index: []

# %%
turnover_parameter_association.tail()
# Out:
#      genus_id  eco_boundary_id  turnover_parameter_id
# 190         2                2                      1
# 191         9                2                      9
# 192         1                2                      1
# 193        13                2                      9
# 194         8                2                      1
